# %%
import pandas as pd
import random
import numpy as np

# %% [markdown]
# ### ipm_provinsi_indonesia

# %%
# Generate meta
def meta_gen_ipm_provinsi_indonesia(ds, l0_prob = 0.99, l1_prob = 0.5, annotator = 'Zaki', id = 'ds0', tablename = 'default', verbose = 0):
    questions = []
    answers = []
    positions = []
    
    pos = 0
    for prov in ds.index:
      if random.uniform(0,1) > l0_prob:
         if verbose > 0:
            print('Not sampled:', prov)
         continue
      #=========== Generate level 0 question-answer set ===========#
      # generate the IPM value since 2010 as a list
      res = []
      for i in range(13):
        res.append(ds.loc[prov,str(i+2010)])

      # randomly select one of these question sentences
      rand = random.uniform(0,1)
      if rand < 0.3:
        qu = 'what is the IPM of '+prov+' since 2010?'
      elif rand < 0.7:
        qu = 'from 2010 what is the IPM of '+prov+'?'
      else:
        qu = 'what is the IPM of '+prov+'?'
      
      # Save result, append 
      questions.append(qu)
      answers.append(res)
      positions.append(pos)

      pos = 1
      for year in ds.columns:
        if random.uniform(0,1) > l1_prob:
           if verbose > 1:
              print('Not sampled:', prov, 'on', year)
           continue
        #=========== Generate level 1 question-answer set ===========#
        
        # randomly select one of these question sentences
        rand = random.uniform(0,1)
        if rand < 0.3:
            qu = 'what is the IPM in '+year+'?'
            res = [str(ds.loc[prov,str(year)])]
        elif rand < 0.5:
            qu = 'what is the IPM of '+prov+' in '+year+'?'
            res = [str(ds.loc[prov,str(year)])]
        elif rand < 0.8:
            qu = 'the IPM in '+year+'?'
            res = [str(ds.loc[prov,str(year)])]
        elif rand < 0.9:
           # Special case, highest value
           qu = 'the highest IPM in '+prov+'?'
           res = [np.max(ds.loc[prov,:])]
        else:
          # Special case, lowest value
           qu = 'the lowest IPM in '+prov+'?'
           res = [np.min(ds.loc[prov,:])]
           
        # Save result, append
        questions.append(qu)
        answers.append(res)
        positions.append(pos)
    result = pd.DataFrame({
       'id' : id,
       'annotator' : annotator,
       'tablename' : tablename,
       'position' : positions,
       'question' : questions,
       'answer' : answers
    })
    return(result)

tablename = 'ipm_provinsi_indonesia'
ds = pd.read_csv('table_csv/ipm_provinsi_indonesia.csv', sep = ';')
ds.set_index('Provinsi', inplace = True)
ds = ds.astype('str')

result = meta_gen_ipm_provinsi_indonesia(ds = ds, l0_prob = 0.5, verbose = 2, tablename=tablename, id = 'ds0001')
fileloc = 'meta_csv/meta_'+tablename+'.csv'
result.to_csv(fileloc, sep = ';', index = False)
print('Total question-answer:', result.shape[0])
# Out:
# Not sampled: ACEH
# Not sampled: SUMATERA UTARA on 2022
# Not sampled: SUMATERA UTARA on 2021
# Not sampled: SUMATERA UTARA on 2020
# Not sampled: SUMATERA UTARA on 2018
# Not sampled: SUMATERA UTARA on 2015
# Not sampled: SUMATERA UTARA on 2012
# Not sampled: SUMATERA UTARA on 2011
# Not sampled: SUMATERA UTARA on 2010
# Not sampled: SUMATERA BARAT on 2019
# Not sampled: SUMATERA BARAT on 2018
# Not sampled: SUMATERA BARAT on 2017
# Not sampled: SUMATERA BARAT on 2012
# Not sampled: SUMATERA BARAT on 2010
# Not sampled: RIAU on 2022
# Not sampled: RIAU on 2020
# Not sampled: RIAU on 2017
# Not sampled: RIAU on 2015
# Not sampled: RIAU on 2014
# Not sampled: RIAU on 2013
# Not sampled: RIAU on 2012
# Not sampled: RIAU on 2011
# Not sampled: JAMBI on 2022
# Not sampled: JAMBI on 2021
# Not sampled: JAMBI on 2020
# Not sampled: JAMBI on 2019
# Not sampled: JAMBI on 2017
# Not sampled: JAMBI on 2015
# Not sampled: JAMBI on 2014
# Not sampled: JAMBI on 2013
# Not sampled: JAMBI on 2011
# Not sampled: JAMBI on 2010
# Not sampled: SUMATERA SELATAN on 2022
# Not sampled: SUMATERA SELATAN on 2020
# Not sampled: SUMATERA SELATAN on 2019
# Not sampled: SUMATERA SELATAN on 2012
# Not sampled: SUMATERA SELATAN on 2011
# Not sampled: BENGKULU
# Not sampled: LAMPUNG on 2022
# Not sampled: LAMPUNG on 2019
# Not sampled: LAMPUNG on 2018
# Not sampled: LAMPUNG on 2017
# Not sampled: LAMPUNG on 2015
# Not sampled: LAMPUNG on 2012
# Not sampled: LAMPUNG on 2011
# Not sampled: LAMPUNG on 2010
# Not sampled: KEP. BANGKA BELITUNG on 2022
# Not sampled: KEP. BANGKA BELITUNG on 2021
# Not sampled: KEP. BANGKA BELITUNG on 2020
# Not sampled: KEP. BANGKA BELITUNG on 2019
# Not sampled: KEP. BANGKA BELITUNG on 2018
# Not sampled: KEP. BANGKA BELITUNG on 2016
# Not sampled: KEP. BANGKA BELITUNG on 2014
# Not sampled: KEP. BANGKA BELITUNG on 2013
# Not sampled: KEP. BANGKA BELITUNG on 2011
# Not sampled: KEP. BANGKA BELITUNG on 2010
# Not sampled: KEP. RIAU on 2020
# Not sampled: KEP. RIAU on 2015
# Not sampled: KEP. RIAU on 2014
# Not sampled: DKI JAKARTA on 2021
# Not sampled: DKI JAKARTA on 2018
# Not sampled: DKI JAKARTA on 2014
# Not sampled: DKI JAKARTA on 2013
# Not sampled: JAWA BARAT
# Not sampled: JAWA TENGAH on 2021
# Not sampled: JAWA TENGAH on 2020
# Not sampled: JAWA TENGAH on 2019
# Not sampled: JAWA TENGAH on 2016
# Not sampled: JAWA TENGAH on 2015
# Not sampled: JAWA TENGAH on 2014
# Not sampled: JAWA TENGAH on 2011
# Not sampled: JAWA TENGAH on 2010
# Not sampled: DI YOGYAKARTA on 2022
# Not sampled: DI YOGYAKARTA on 2021
# Not sampled: DI YOGYAKARTA on 2020
# Not sampled: DI YOGYAKARTA on 2019
# Not sampled: DI YOGYAKARTA on 2016
# Not sampled: DI YOGYAKARTA on 2014
# Not sampled: DI YOGYAKARTA on 2011
# Not sampled: JAWA TIMUR on 2017
# Not sampled: JAWA TIMUR on 2016
# Not sampled: JAWA TIMUR on 2013
# Not sampled: JAWA TIMUR on 2010
# Not sampled: BANTEN on 2021
# Not sampled: BANTEN on 2018
# Not sampled: BANTEN on 2017
# Not sampled: BANTEN on 2013
# Not sampled: BANTEN on 2011
# Not sampled: BALI
# Not sampled: NUSA TENGGARA BARAT on 2019
# Not sampled: NUSA TENGGARA BARAT on 2018
# Not sampled: NUSA TENGGARA BARAT on 2016
# Not sampled: NUSA TENGGARA BARAT on 2014
# Not sampled: NUSA TENGGARA BARAT on 2013
# Not sampled: NUSA TENGGARA BARAT on 2010
# Not sampled: NUSA TENGGARA TIMUR
# Not sampled: KALIMANTAN BARAT on 2022
# Not sampled: KALIMANTAN BARAT on 2017
# Not sampled: KALIMANTAN BARAT on 2016
# Not sampled: KALIMANTAN BARAT on 2012
# Not sampled: KALIMANTAN BARAT on 2011
# Not sampled: KALIMANTAN BARAT on 2010
# Not sampled: KALIMANTAN TENGAH on 2019
# Not sampled: KALIMANTAN TENGAH on 2018
# Not sampled: KALIMANTAN TENGAH on 2017
# Not sampled: KALIMANTAN TENGAH on 2016
# Not sampled: KALIMANTAN TENGAH on 2015
# Not sampled: KALIMANTAN TENGAH on 2013
# Not sampled: KALIMANTAN TENGAH on 2012
# Not sampled: KALIMANTAN TENGAH on 2011
# Not sampled: KALIMANTAN TENGAH on 2010
# Not sampled: KALIMANTAN SELATAN
# Not sampled: KALIMANTAN TIMUR on 2022
# Not sampled: KALIMANTAN TIMUR on 2018
# Not sampled: KALIMANTAN TIMUR on 2010
# Not sampled: KALIMANTAN UTARA
# Not sampled: SULAWESI UTARA on 2021
# Not sampled: SULAWESI UTARA on 2019
# Not sampled: SULAWESI UTARA on 2016
# Not sampled: SULAWESI UTARA on 2015
# Not sampled: SULAWESI UTARA on 2014
# Not sampled: SULAWESI UTARA on 2013
# Not sampled: SULAWESI UTARA on 2012
# Not sampled: SULAWESI UTARA on 2011
# Not sampled: SULAWESI UTARA on 2010
# Not sampled: SULAWESI TENGAH
# Not sampled: SULAWESI SELATAN
# Not sampled: SULAWESI TENGGARA
# Not sampled: GORONTALO
# Not sampled: SULAWESI BARAT on 2020
# Not sampled: SULAWESI BARAT on 2016
# Not sampled: SULAWESI BARAT on 2013
# Not sampled: SULAWESI BARAT on 2011
# Not sampled: MALUKU on 2019
# Not sampled: MALUKU on 2018
# Not sampled: MALUKU on 2016
# Not sampled: MALUKU on 2013
# Not sampled: MALUKU on 2012
# Not sampled: MALUKU on 2010
# Not sampled: MALUKU UTARA
# Not sampled: PAPUA BARAT on 2020
# Not sampled: PAPUA BARAT on 2018
# Not sampled: PAPUA BARAT on 2012
# Not sampled: PAPUA BARAT on 2010
# Not sampled: PAPUA
# Not sampled: INDONESIA on 2022
# Not sampled: INDONESIA on 2021
# Not sampled: INDONESIA on 2019
# Not sampled: INDONESIA on 2016
# Not sampled: INDONESIA on 2015
# Not sampled: INDONESIA on 2014
# Not sampled: INDONESIA on 2012
# Total question-answer: 169

# %% [markdown]
# ### inflasi_kota_indonesia

# %%
# Generate meta
def meta_gen_inflasi_kota_indonesia(ds, l0_prob = 0.99, l1_prob = 0.5, annotator = 'Zaki', id = 'ds0', tablename = 'default', verbose = 0):
    questions = []
    answers = []
    positions = []
    
    pos = 0
    for idx in ds.index:
      if random.uniform(0,1) > l0_prob:
         if verbose > 0:
            print('Not sampled:', idx)
         continue
      #=========== Generate level 0 question-answer set ===========#
      # generate the inflation rate value since 2020 as a list
      res = []
      for i in range(ds.shape[1]):
        res.append(ds.loc[idx,str(i+2020)])

      # randomly select one of these question sentences
      rand = random.uniform(0,1)
      if rand < 0.3:
        qu = 'what is the inflation rate of '+idx+' since 2020?'
      elif rand < 0.5:
        qu = 'from 2020 what is the inflation number of '+idx+'?'
      elif rand < 0.7:
        qu = 'since 2020 what is the inflation rate of '+idx+'?'
      else:
        qu = 'what is the inflation rate of '+idx+'?'
      
      # Save result, append 
      questions.append(qu)
      answers.append(res)
      positions.append(pos)

      pos = 1
      for col in ds.columns:
        if random.uniform(0,1) > l1_prob:
           if verbose > 1:
              print('Not sampled:', idx, 'on', col)
           continue
        #=========== Generate level 1 question-answer set ===========#
        res = [str(ds.loc[idx,str(col)])]
        
        # randomly select one of these question sentences
        rand = random.uniform(0,1)
        if rand < 0.3:
            qu = 'what is the inflation rate in '+col+'?'
        elif rand < 0.7:
            qu = 'what is the inflation of '+idx+' in '+col+'?'
        else:
            qu = 'the inflation rate in '+col+'?'
        
        # Save result, append
        questions.append(qu)
        answers.append(res)
        positions.append(pos)
    result = pd.DataFrame({
       'id' : id,
       'annotator' : annotator,
       'tablename' : tablename,
       'position' : positions,
       'question' : questions,
       'answer' : answers
    })
    return(result)

tablename = 'inflasi_kota_indonesia'
ds = pd.read_csv('table_csv/inflasi_kota_indonesia.csv', sep = ';')
ds.set_index('kota', inplace = True)
ds = ds.astype('str')

result = meta_gen_inflasi_kota_indonesia(ds = ds, l0_prob = 0.90, verbose = 2, tablename=tablename, id = 'ds0002')
fileloc = 'meta_csv/meta_'+tablename+'.csv'
result.to_csv(fileloc, sep = ';', index = False)
print('Total question-answer:', result.shape[0])
# Out:
# Not sampled: KOTA MEULABOH on 2021
# Not sampled: KOTA LHOKSEUMAWE on 2022
# Not sampled: KOTA LHOKSEUMAWE on 2021
# Not sampled: KOTA SIBOLGA on 2021
# Not sampled: KOTA SIBOLGA on 2020
# Not sampled: KOTA PEMATANG SIANTAR on 2022
# Not sampled: KOTA MEDAN on 2022
# Not sampled: KOTA PADANGSIDIMPUAN on 2021
# Not sampled: KOTA PADANGSIDIMPUAN on 2020
# Not sampled: KOTA GUNUNGSITOLI on 2020
# Not sampled: KOTA PADANG on 2022
# Not sampled: KOTA BUKITTINGGI on 2021
# Not sampled: TEMBILAHAN
# Not sampled: KOTA PEKANBARU on 2022
# Not sampled: KOTA PEKANBARU on 2021
# Not sampled: KOTA PEKANBARU on 2020
# Not sampled: KOTA DUMAI on 2022
# Not sampled: BUNGO on 2022
# Not sampled: BUNGO on 2020
# Not sampled: KOTA JAMBI on 2022
# Not sampled: KOTA JAMBI on 2021
# Not sampled: KOTA PALEMBANG on 2022
# Not sampled: KOTA PALEMBANG on 2020
# Not sampled: KOTA LUBUKLINGGAU on 2021
# Not sampled: KOTA LUBUKLINGGAU on 2020
# Not sampled: KOTA BENGKULU on 2022
# Not sampled: KOTA BENGKULU on 2021
# Not sampled: KOTA BENGKULU on 2020
# Not sampled: KOTA BANDAR LAMPUNG on 2021
# Not sampled: KOTA BANDAR LAMPUNG on 2020
# Not sampled: KOTA METRO on 2021
# Not sampled: KOTA METRO on 2020
# Not sampled: TANJUNG PANDAN on 2022
# Not sampled: KOTA PANGKAL PINANG on 2022
# Not sampled: KOTA PANGKAL PINANG on 2021
# Not sampled: KOTA TANJUNG PINANG on 2022
# Not sampled: KOTA TANJUNG PINANG on 2021
# Not sampled: KOTA TANJUNG PINANG on 2020
# Not sampled: DKI JAKARTA on 2022
# Not sampled: DKI JAKARTA on 2021
# Not sampled: DKI JAKARTA on 2020
# Not sampled: KOTA BOGOR on 2022
# Not sampled: KOTA BOGOR on 2021
# Not sampled: KOTA SUKABUMI on 2022
# Not sampled: KOTA SUKABUMI on 2021
# Not sampled: KOTA SUKABUMI on 2020
# Not sampled: KOTA BANDUNG
# Not sampled: KOTA CIREBON on 2020
# Not sampled: KOTA DEPOK on 2022
# Not sampled: KOTA TASIKMALAYA on 2022
# Not sampled: KOTA TASIKMALAYA on 2020
# Not sampled: CILACAP on 2022
# Not sampled: PURWOKERTO on 2022
# Not sampled: PURWOKERTO on 2021
# Not sampled: PURWOKERTO on 2020
# Not sampled: KUDUS on 2021
# Not sampled: KOTA SURAKARTA on 2022
# Not sampled: KOTA SURAKARTA on 2020
# Not sampled: KOTA SEMARANG on 2020
# Not sampled: KOTA TEGAL on 2021
# Not sampled: KOTA YOGYAKARTA on 2021
# Not sampled: KOTA YOGYAKARTA on 2020
# Not sampled: JEMBER on 2021
# Not sampled: JEMBER on 2020
# Not sampled: BANYUWANGI on 2022
# Not sampled: BANYUWANGI on 2021
# Not sampled: BANYUWANGI on 2020
# Not sampled: SUMENEP on 2022
# Not sampled: SUMENEP on 2020
# Not sampled: KOTA KEDIRI on 2022
# Not sampled: KOTA KEDIRI on 2021
# Not sampled: KOTA PROBOLINGGO on 2022
# Not sampled: KOTA PROBOLINGGO on 2020
# Not sampled: KOTA MADIUN on 2022
# Not sampled: KOTA SURABAYA
# Not sampled: KOTA TANGERANG on 2022
# Not sampled: KOTA TANGERANG on 2021
# Not sampled: KOTA CILEGON on 2022
# Not sampled: KOTA CILEGON on 2020
# Not sampled: KOTA SERANG on 2022
# Not sampled: KOTA SERANG on 2020
# Not sampled: SINGARAJA on 2021
# Not sampled: SINGARAJA on 2020
# Not sampled: KOTA DENPASAR on 2022
# Not sampled: KOTA DENPASAR on 2021
# Not sampled: KOTA BIMA on 2022
# Not sampled: KOTA BIMA on 2020
# Not sampled: WAINGAPU on 2022
# Not sampled: WAINGAPU on 2020
# Not sampled: MAUMERE on 2020
# Not sampled: KOTA KUPANG
# Not sampled: SINTANG on 2021
# Not sampled: SINTANG on 2020
# Not sampled: KOTA PONTIANAK on 2020
# Not sampled: KOTA SINGKAWANG on 2022
# Not sampled: KOTA SINGKAWANG on 2020
# Not sampled: SAMPIT on 2022
# Not sampled: SAMPIT on 2021
# Not sampled: SAMPIT on 2020
# Not sampled: TANJUNG on 2021
# Not sampled: KOTA BANJARMASIN on 2022
# Not sampled: KOTA BANJARMASIN on 2021
# Not sampled: KOTA BANJARMASIN on 2020
# Not sampled: KOTA BALIKPAPAN on 2022
# Not sampled: KOTA SAMARINDA on 2022
# Not sampled: KOTA SAMARINDA on 2020
# Not sampled: TANJUNG SELOR
# Not sampled: KOTA TARAKAN on 2022
# Not sampled: KOTA TARAKAN on 2021
# Not sampled: KOTA MANADO on 2022
# Not sampled: KOTA KOTAMOBAGU on 2021
# Not sampled: LUWUK on 2020
# Not sampled: KOTA PALU on 2021
# Not sampled: BULUKUMBA on 2022
# Not sampled: BULUKUMBA on 2020
# Not sampled: WATAMPONE on 2022
# Not sampled: WATAMPONE on 2021
# Not sampled: WATAMPONE on 2020
# Not sampled: KOTA MAKASSAR on 2022
# Not sampled: KOTA MAKASSAR on 2021
# Not sampled: KOTA PARE-PARE on 2020
# Not sampled: KOTA PALOPO on 2022
# Not sampled: KOTA KENDARI on 2022
# Not sampled: KOTA KENDARI on 2020
# Not sampled: KOTA BUA-BAU on 2022
# Not sampled: KOTA GORONTALO on 2022
# Not sampled: KOTA GORONTALO on 2021
# Not sampled: KOTA GORONTALO on 2020
# Not sampled: MAMUJU on 2021
# Not sampled: MAMUJU on 2020
# Not sampled: KOTA AMBON on 2022
# Not sampled: KOTA TUAL on 2020
# Not sampled: KOTA TERNATE on 2021
# Not sampled: KOTA TERNATE on 2020
# Not sampled: MANOKWARI on 2021
# Not sampled: TIMIKA on 2022
# Not sampled: KOTA JAYAPURA on 2021
# Not sampled: KOTA JAYAPURA on 2020
# Not sampled: INDONESIA on 2021
# Not sampled: INDONESIA on 2020
# Total question-answer: 209

# %% [markdown]
# ### angka_harapan_hidup_provinsi_indonesia

# %%
# Generate meta
def meta_gen_ahh_provinsi_indonesia(ds, l0_prob = 0.99, l1_prob = 0.5, annotator = 'Zaki', id = 'ds0', tablename = 'default', verbose = 0):
    questions = []
    answers = []
    positions = []
    
    pos = 0
    for it, _ in enumerate(ds.index):
      idx = ds.loc[it,'Provinsi']
      if random.uniform(0,1) > l0_prob:
         if verbose > 0:
            print('Not sampled:', idx)
         continue
      #=========== Generate level 0 question-answer set ===========#
      # generate the AHH value since 2010 as a list
      res = []
      for i in range((ds.shape[1]-2)):
        res.append(ds.loc[it,str(i+2010)])

      # randomly select one of these question sentences
      rand = random.uniform(0,1)

      jk = ds.loc[it,'Jenis Kelamin']

      if rand < 0.3:
        qu = 'what is the life expectancy of '+jk+' living in '+idx+' since 2020?'
      elif rand < 0.5:
        qu = 'from 2020 what is the expected life of '+jk+' in '+idx+'?'
      elif rand < 0.7:
        qu = 'since 2020 what is the life expectancy for '+jk+' in '+idx+'?'
      else:
        qu = 'what is the '+jk+' life expectancy in '+idx+'?'
      
      # Save result, append 
      questions.append(qu)
      answers.append(res)
      positions.append(pos)

      pos = 1
      for col in ds.columns:
        if col == 'Jenis Kelamin':
           continue
        if random.uniform(0,1) > l1_prob:
           if verbose > 1:
              print('Not sampled:', idx, 'on', col)
           continue
        #=========== Generate level 1 question-answer set ===========#
        res = [str(ds.loc[it,str(col)])]
        
        # randomly select one of these question sentences
        rand = random.uniform(0,1)
        if rand < 0.3:
            qu = 'what is the life expectancy in '+col+' for '+jk+'?'
        elif rand < 0.7:
            qu = 'what is the life expectancy of '+jk+ ' in '+idx+' in '+col+'?'
        else:
            qu = jk+' life expectancy in '+col+'?'
        
        # Save result, append
        questions.append(qu)
        answers.append(res)
        positions.append(pos)
    result = pd.DataFrame({
       'id' : id,
       'annotator' : annotator,
       'tablename' : tablename,
       'position' : positions,
       'question' : questions,
       'answer' : answers
    })
    return(result)

tablename = 'angka_harapan_hidup_provinsi_indonesia'
ds = pd.read_csv('table_csv/angka_harapan_hidup_provinsi_indonesia.csv', sep = ';')
ds = ds.astype('str')

result = meta_gen_ahh_provinsi_indonesia(ds = ds, l0_prob = 0.90, verbose = 2, tablename=tablename, id = 'ds0003')
fileloc = 'meta_csv/meta_'+tablename+'.csv'
result.to_csv(fileloc, sep = ';', index = False)
print('Total question-answer:', result.shape[0])
# Out:
# Not sampled: ACEH on Provinsi
# Not sampled: ACEH on 2022
# Not sampled: ACEH on 2021
# Not sampled: ACEH on 2019
# Not sampled: ACEH on 2015
# Not sampled: ACEH on 2014
# Not sampled: ACEH on 2013
# Not sampled: ACEH on 2011
# Not sampled: SUMATERA UTARA
# Not sampled: SUMATERA BARAT on 2020
# Not sampled: SUMATERA BARAT on 2019
# Not sampled: SUMATERA BARAT on 2018
# Not sampled: SUMATERA BARAT on 2017
# Not sampled: SUMATERA BARAT on 2016
# Not sampled: SUMATERA BARAT on 2014
# Not sampled: SUMATERA BARAT on 2010
# Not sampled: RIAU
# Not sampled: JAMBI on 2022
# Not sampled: JAMBI on 2019
# Not sampled: JAMBI on 2018
# Not sampled: JAMBI on 2016
# Not sampled: JAMBI on 2015
# Not sampled: JAMBI on 2013
# Not sampled: JAMBI on 2012
# Not sampled: JAMBI on 2011
# Not sampled: JAMBI on 2010
# Not sampled: SUMATERA SELATAN on 2018
# Not sampled: SUMATERA SELATAN on 2017
# Not sampled: SUMATERA SELATAN on 2016
# Not sampled: SUMATERA SELATAN on 2015
# Not sampled: SUMATERA SELATAN on 2014
# Not sampled: SUMATERA SELATAN on 2010
# Not sampled: BENGKULU on 2022
# Not sampled: BENGKULU on 2020
# Not sampled: BENGKULU on 2019
# Not sampled: BENGKULU on 2016
# Not sampled: BENGKULU on 2015
# Not sampled: LAMPUNG on Provinsi
# Not sampled: LAMPUNG on 2022
# Not sampled: LAMPUNG on 2021
# Not sampled: LAMPUNG on 2018
# Not sampled: LAMPUNG on 2017
# Not sampled: LAMPUNG on 2016
# Not sampled: LAMPUNG on 2015
# Not sampled: LAMPUNG on 2011
# Not sampled: LAMPUNG on 2010
# Not sampled: KEP. BANGKA BELITUNG on Provinsi
# Not sampled: KEP. BANGKA BELITUNG on 2021
# Not sampled: KEP. BANGKA BELITUNG on 2020
# Not sampled: KEP. BANGKA BELITUNG on 2019
# Not sampled: KEP. BANGKA BELITUNG on 2018
# Not sampled: KEP. BANGKA BELITUNG on 2016
# Not sampled: KEP. BANGKA BELITUNG on 2015
# Not sampled: KEP. BANGKA BELITUNG on 2014
# Not sampled: KEP. BANGKA BELITUNG on 2013
# Not sampled: KEP. BANGKA BELITUNG on 2012
# Not sampled: KEP. BANGKA BELITUNG on 2011
# Not sampled: KEP. BANGKA BELITUNG on 2010
# Not sampled: KEP. RIAU on 2017
# Not sampled: KEP. RIAU on 2012
# Not sampled: KEP. RIAU on 2010
# Not sampled: DKI JAKARTA on 2022
# Not sampled: DKI JAKARTA on 2021
# Not sampled: DKI JAKARTA on 2020
# Not sampled: DKI JAKARTA on 2018
# Not sampled: DKI JAKARTA on 2015
# Not sampled: DKI JAKARTA on 2014
# Not sampled: DKI JAKARTA on 2013
# Not sampled: JAWA BARAT on Provinsi
# Not sampled: JAWA BARAT on 2019
# Not sampled: JAWA BARAT on 2018
# Not sampled: JAWA BARAT on 2014
# Not sampled: JAWA BARAT on 2013
# Not sampled: JAWA TENGAH on 2020
# Not sampled: JAWA TENGAH on 2019
# Not sampled: JAWA TENGAH on 2018
# Not sampled: JAWA TENGAH on 2015
# Not sampled: JAWA TENGAH on 2014
# Not sampled: JAWA TENGAH on 2013
# Not sampled: JAWA TENGAH on 2012
# Not sampled: JAWA TENGAH on 2010
# Not sampled: DI YOGYAKARTA on 2022
# Not sampled: DI YOGYAKARTA on 2021
# Not sampled: DI YOGYAKARTA on 2018
# Not sampled: DI YOGYAKARTA on 2017
# Not sampled: DI YOGYAKARTA on 2015
# Not sampled: DI YOGYAKARTA on 2012
# Not sampled: DI YOGYAKARTA on 2010
# Not sampled: JAWA TIMUR on Provinsi
# Not sampled: JAWA TIMUR on 2021
# Not sampled: JAWA TIMUR on 2020
# Not sampled: JAWA TIMUR on 2019
# Not sampled: JAWA TIMUR on 2018
# Not sampled: JAWA TIMUR on 2017
# Not sampled: JAWA TIMUR on 2016
# Not sampled: JAWA TIMUR on 2011
# Not sampled: BANTEN
# Not sampled: BALI on Provinsi
# Not sampled: BALI on 2022
# Not sampled: BALI on 2019
# Not sampled: BALI on 2018
# Not sampled: BALI on 2017
# Not sampled: BALI on 2016
# Not sampled: BALI on 2013
# Not sampled: BALI on 2011
# Not sampled: BALI on 2010
# Not sampled: NUSA TENGGARA BARAT on Provinsi
# Not sampled: NUSA TENGGARA BARAT on 2021
# Not sampled: NUSA TENGGARA BARAT on 2019
# Not sampled: NUSA TENGGARA BARAT on 2016
# Not sampled: NUSA TENGGARA BARAT on 2014
# Not sampled: NUSA TENGGARA BARAT on 2012
# Not sampled: NUSA TENGGARA BARAT on 2011
# Not sampled: NUSA TENGGARA BARAT on 2010
# Not sampled: NUSA TENGGARA TIMUR on 2020
# Not sampled: NUSA TENGGARA TIMUR on 2016
# Not sampled: NUSA TENGGARA TIMUR on 2015
# Not sampled: NUSA TENGGARA TIMUR on 2014
# Not sampled: NUSA TENGGARA TIMUR on 2012
# Not sampled: NUSA TENGGARA TIMUR on 2011
# Not sampled: KALIMANTAN BARAT
# Not sampled: KALIMANTAN TENGAH on 2018
# Not sampled: KALIMANTAN TENGAH on 2016
# Not sampled: KALIMANTAN TENGAH on 2015
# Not sampled: KALIMANTAN TENGAH on 2013
# Not sampled: KALIMANTAN TENGAH on 2012
# Not sampled: KALIMANTAN TENGAH on 2011
# Not sampled: KALIMANTAN SELATAN on Provinsi
# Not sampled: KALIMANTAN SELATAN on 2021
# Not sampled: KALIMANTAN SELATAN on 2020
# Not sampled: KALIMANTAN SELATAN on 2017
# Not sampled: KALIMANTAN SELATAN on 2015
# Not sampled: KALIMANTAN SELATAN on 2014
# Not sampled: KALIMANTAN SELATAN on 2013
# Not sampled: KALIMANTAN SELATAN on 2012
# Not sampled: KALIMANTAN SELATAN on 2011
# Not sampled: KALIMANTAN SELATAN on 2010
# Not sampled: KALIMANTAN TIMUR on Provinsi
# Not sampled: KALIMANTAN TIMUR on 2022
# Not sampled: KALIMANTAN TIMUR on 2020
# Not sampled: KALIMANTAN TIMUR on 2019
# Not sampled: KALIMANTAN TIMUR on 2017
# Not sampled: KALIMANTAN TIMUR on 2016
# Not sampled: KALIMANTAN TIMUR on 2014
# Not sampled: KALIMANTAN TIMUR on 2010
# Not sampled: KALIMANTAN UTARA on 2021
# Not sampled: KALIMANTAN UTARA on 2020
# Not sampled: KALIMANTAN UTARA on 2019
# Not sampled: KALIMANTAN UTARA on 2017
# Not sampled: KALIMANTAN UTARA on 2016
# Not sampled: KALIMANTAN UTARA on 2014
# Not sampled: KALIMANTAN UTARA on 2013
# Not sampled: KALIMANTAN UTARA on 2012
# Not sampled: KALIMANTAN UTARA on 2011
# Not sampled: KALIMANTAN UTARA on 2010
# Not sampled: SULAWESI UTARA on Provinsi
# Not sampled: SULAWESI UTARA on 2021
# Not sampled: SULAWESI UTARA on 2020
# Not sampled: SULAWESI UTARA on 2017
# Not sampled: SULAWESI UTARA on 2015
# Not sampled: SULAWESI UTARA on 2014
# Not sampled: SULAWESI UTARA on 2013
# Not sampled: SULAWESI UTARA on 2012
# Not sampled: SULAWESI UTARA on 2010
# Not sampled: SULAWESI TENGAH on 2021
# Not sampled: SULAWESI TENGAH on 2020
# Not sampled: SULAWESI TENGAH on 2016
# Not sampled: SULAWESI TENGAH on 2015
# Not sampled: SULAWESI TENGAH on 2014
# Not sampled: SULAWESI TENGAH on 2013
# Not sampled: SULAWESI TENGAH on 2011
# Not sampled: SULAWESI TENGAH on 2010
# Not sampled: SULAWESI SELATAN on Provinsi
# Not sampled: SULAWESI SELATAN on 2022
# Not sampled: SULAWESI SELATAN on 2021
# Not sampled: SULAWESI SELATAN on 2020
# Not sampled: SULAWESI SELATAN on 2019
# Not sampled: SULAWESI SELATAN on 2017
# Not sampled: SULAWESI SELATAN on 2016
# Not sampled: SULAWESI SELATAN on 2013
# Not sampled: SULAWESI SELATAN on 2012
# Not sampled: SULAWESI SELATAN on 2011
# Not sampled: SULAWESI TENGGARA on 2021
# Not sampled: SULAWESI TENGGARA on 2020
# Not sampled: SULAWESI TENGGARA on 2019
# Not sampled: SULAWESI TENGGARA on 2017
# Not sampled: SULAWESI TENGGARA on 2014
# Not sampled: SULAWESI TENGGARA on 2010
# Not sampled: GORONTALO on 2022
# Not sampled: GORONTALO on 2020
# Not sampled: GORONTALO on 2017
# Not sampled: GORONTALO on 2015
# Not sampled: GORONTALO on 2013
# Not sampled: GORONTALO on 2011
# Not sampled: GORONTALO on 2010
# Not sampled: SULAWESI BARAT on Provinsi
# Not sampled: SULAWESI BARAT on 2022
# Not sampled: SULAWESI BARAT on 2018
# Not sampled: SULAWESI BARAT on 2017
# Not sampled: SULAWESI BARAT on 2015
# Not sampled: SULAWESI BARAT on 2014
# Not sampled: SULAWESI BARAT on 2012
# Not sampled: SULAWESI BARAT on 2011
# Not sampled: SULAWESI BARAT on 2010
# Not sampled: MALUKU on Provinsi
# Not sampled: MALUKU on 2020
# Not sampled: MALUKU on 2019
# Not sampled: MALUKU on 2016
# Not sampled: MALUKU on 2015
# Not sampled: MALUKU on 2012
# Not sampled: MALUKU on 2011
# Not sampled: MALUKU on 2010
# Not sampled: MALUKU UTARA
# Not sampled: PAPUA BARAT on Provinsi
# Not sampled: PAPUA BARAT on 2021
# Not sampled: PAPUA BARAT on 2019
# Not sampled: PAPUA BARAT on 2018
# Not sampled: PAPUA BARAT on 2017
# Not sampled: PAPUA BARAT on 2013
# Not sampled: PAPUA BARAT on 2010
# Not sampled: PAPUA
# Not sampled: INDONESIA on Provinsi
# Not sampled: INDONESIA on 2022
# Not sampled: INDONESIA on 2020
# Not sampled: INDONESIA on 2018
# Not sampled: INDONESIA on 2016
# Not sampled: INDONESIA on 2015
# Not sampled: INDONESIA on 2014
# Not sampled: ACEH on Provinsi
# Not sampled: ACEH on 2020
# Not sampled: ACEH on 2019
# Not sampled: ACEH on 2018
# Not sampled: ACEH on 2016
# Not sampled: ACEH on 2015
# Not sampled: ACEH on 2014
# Not sampled: ACEH on 2010
# Not sampled: SUMATERA UTARA on Provinsi
# Not sampled: SUMATERA UTARA on 2018
# Not sampled: SUMATERA UTARA on 2017
# Not sampled: SUMATERA UTARA on 2016
# Not sampled: SUMATERA UTARA on 2015
# Not sampled: SUMATERA UTARA on 2013
# Not sampled: SUMATERA UTARA on 2012
# Not sampled: SUMATERA UTARA on 2011
# Not sampled: SUMATERA BARAT on 2021
# Not sampled: SUMATERA BARAT on 2019
# Not sampled: SUMATERA BARAT on 2017
# Not sampled: SUMATERA BARAT on 2016
# Not sampled: SUMATERA BARAT on 2015
# Not sampled: SUMATERA BARAT on 2012
# Not sampled: SUMATERA BARAT on 2011
# Not sampled: SUMATERA BARAT on 2010
# Not sampled: RIAU on 2020
# Not sampled: RIAU on 2018
# Not sampled: RIAU on 2017
# Not sampled: RIAU on 2015
# Not sampled: RIAU on 2013
# Not sampled: RIAU on 2012
# Not sampled: RIAU on 2011
# Not sampled: JAMBI on Provinsi
# Not sampled: JAMBI on 2021
# Not sampled: JAMBI on 2020
# Not sampled: JAMBI on 2016
# Not sampled: JAMBI on 2012
# Not sampled: JAMBI on 2011
# Not sampled: SUMATERA SELATAN on Provinsi
# Not sampled: SUMATERA SELATAN on 2021
# Not sampled: SUMATERA SELATAN on 2019
# Not sampled: SUMATERA SELATAN on 2016
# Not sampled: SUMATERA SELATAN on 2013
# Not sampled: SUMATERA SELATAN on 2010
# Not sampled: BENGKULU on Provinsi
# Not sampled: BENGKULU on 2022
# Not sampled: BENGKULU on 2021
# Not sampled: BENGKULU on 2018
# Not sampled: BENGKULU on 2010
# Not sampled: LAMPUNG on 2021
# Not sampled: LAMPUNG on 2020
# Not sampled: LAMPUNG on 2015
# Not sampled: LAMPUNG on 2013
# Not sampled: LAMPUNG on 2012
# Not sampled: LAMPUNG on 2011
# Not sampled: LAMPUNG on 2010
# Not sampled: KEP. BANGKA BELITUNG on 2022
# Not sampled: KEP. BANGKA BELITUNG on 2020
# Not sampled: KEP. BANGKA BELITUNG on 2019
# Not sampled: KEP. BANGKA BELITUNG on 2018
# Not sampled: KEP. BANGKA BELITUNG on 2013
# Not sampled: KEP. BANGKA BELITUNG on 2010
# Not sampled: KEP. RIAU on Provinsi
# Not sampled: KEP. RIAU on 2020
# Not sampled: KEP. RIAU on 2019
# Not sampled: KEP. RIAU on 2018
# Not sampled: KEP. RIAU on 2014
# Not sampled: KEP. RIAU on 2013
# Not sampled: DKI JAKARTA on Provinsi
# Not sampled: DKI JAKARTA on 2021
# Not sampled: DKI JAKARTA on 2018
# Not sampled: DKI JAKARTA on 2017
# Not sampled: DKI JAKARTA on 2016
# Not sampled: DKI JAKARTA on 2015
# Not sampled: DKI JAKARTA on 2012
# Not sampled: DKI JAKARTA on 2011
# Not sampled: DKI JAKARTA on 2010
# Not sampled: JAWA BARAT on Provinsi
# Not sampled: JAWA BARAT on 2022
# Not sampled: JAWA BARAT on 2021
# Not sampled: JAWA BARAT on 2019
# Not sampled: JAWA BARAT on 2018
# Not sampled: JAWA BARAT on 2017
# Not sampled: JAWA BARAT on 2016
# Not sampled: JAWA BARAT on 2014
# Not sampled: JAWA BARAT on 2013
# Not sampled: JAWA TENGAH on Provinsi
# Not sampled: JAWA TENGAH on 2022
# Not sampled: JAWA TENGAH on 2020
# Not sampled: JAWA TENGAH on 2016
# Not sampled: JAWA TENGAH on 2015
# Not sampled: JAWA TENGAH on 2013
# Not sampled: JAWA TENGAH on 2011
# Not sampled: DI YOGYAKARTA on 2020
# Not sampled: DI YOGYAKARTA on 2013
# Not sampled: DI YOGYAKARTA on 2011
# Not sampled: JAWA TIMUR on Provinsi
# Not sampled: JAWA TIMUR on 2020
# Not sampled: JAWA TIMUR on 2018
# Not sampled: JAWA TIMUR on 2016
# Not sampled: JAWA TIMUR on 2015
# Not sampled: JAWA TIMUR on 2014
# Not sampled: JAWA TIMUR on 2011
# Not sampled: BANTEN on Provinsi
# Not sampled: BANTEN on 2020
# Not sampled: BANTEN on 2019
# Not sampled: BANTEN on 2018
# Not sampled: BANTEN on 2017
# Not sampled: BANTEN on 2015
# Not sampled: BANTEN on 2012
# Not sampled: BANTEN on 2011
# Not sampled: BANTEN on 2010
# Not sampled: BALI on 2022
# Not sampled: BALI on 2021
# Not sampled: BALI on 2020
# Not sampled: BALI on 2019
# Not sampled: BALI on 2017
# Not sampled: BALI on 2016
# Not sampled: BALI on 2015
# Not sampled: BALI on 2013
# Not sampled: BALI on 2011
# Not sampled: NUSA TENGGARA BARAT
# Not sampled: NUSA TENGGARA TIMUR
# Not sampled: KALIMANTAN BARAT on Provinsi
# Not sampled: KALIMANTAN BARAT on 2021
# Not sampled: KALIMANTAN BARAT on 2019
# Not sampled: KALIMANTAN BARAT on 2018
# Not sampled: KALIMANTAN BARAT on 2017
# Not sampled: KALIMANTAN BARAT on 2013
# Not sampled: KALIMANTAN BARAT on 2011
# Not sampled: KALIMANTAN BARAT on 2010
# Not sampled: KALIMANTAN TENGAH on Provinsi
# Not sampled: KALIMANTAN TENGAH on 2021
# Not sampled: KALIMANTAN TENGAH on 2018
# Not sampled: KALIMANTAN TENGAH on 2017
# Not sampled: KALIMANTAN TENGAH on 2015
# Not sampled: KALIMANTAN TENGAH on 2014
# Not sampled: KALIMANTAN TENGAH on 2012
# Not sampled: KALIMANTAN TENGAH on 2011
# Not sampled: KALIMANTAN SELATAN
# Not sampled: KALIMANTAN TIMUR on 2021
# Not sampled: KALIMANTAN TIMUR on 2020
# Not sampled: KALIMANTAN TIMUR on 2016
# Not sampled: KALIMANTAN TIMUR on 2014
# Not sampled: KALIMANTAN TIMUR on 2012
# Not sampled: KALIMANTAN TIMUR on 2011
# Not sampled: KALIMANTAN TIMUR on 2010
# Not sampled: KALIMANTAN UTARA on 2022
# Not sampled: KALIMANTAN UTARA on 2020
# Not sampled: KALIMANTAN UTARA on 2019
# Not sampled: KALIMANTAN UTARA on 2016
# Not sampled: KALIMANTAN UTARA on 2015
# Not sampled: KALIMANTAN UTARA on 2013
# Not sampled: KALIMANTAN UTARA on 2012
# Not sampled: KALIMANTAN UTARA on 2011
# Not sampled: SULAWESI UTARA on Provinsi
# Not sampled: SULAWESI UTARA on 2021
# Not sampled: SULAWESI UTARA on 2018
# Not sampled: SULAWESI UTARA on 2017
# Not sampled: SULAWESI UTARA on 2016
# Not sampled: SULAWESI UTARA on 2013
# Not sampled: SULAWESI UTARA on 2012
# Not sampled: SULAWESI UTARA on 2011
# Not sampled: SULAWESI TENGAH on 2021
# Not sampled: SULAWESI TENGAH on 2020
# Not sampled: SULAWESI TENGAH on 2018
# Not sampled: SULAWESI TENGAH on 2016
# Not sampled: SULAWESI TENGAH on 2015
# Not sampled: SULAWESI TENGAH on 2014
# Not sampled: SULAWESI TENGAH on 2011
# Not sampled: SULAWESI TENGAH on 2010
# Not sampled: SULAWESI SELATAN on 2020
# Not sampled: SULAWESI SELATAN on 2017
# Not sampled: SULAWESI SELATAN on 2015
# Not sampled: SULAWESI SELATAN on 2014
# Not sampled: SULAWESI SELATAN on 2013
# Not sampled: SULAWESI SELATAN on 2012
# Not sampled: SULAWESI SELATAN on 2010
# Not sampled: SULAWESI TENGGARA on 2022
# Not sampled: SULAWESI TENGGARA on 2021
# Not sampled: SULAWESI TENGGARA on 2020
# Not sampled: SULAWESI TENGGARA on 2019
# Not sampled: SULAWESI TENGGARA on 2018
# Not sampled: SULAWESI TENGGARA on 2017
# Not sampled: SULAWESI TENGGARA on 2015
# Not sampled: GORONTALO on Provinsi
# Not sampled: GORONTALO on 2022
# Not sampled: GORONTALO on 2020
# Not sampled: GORONTALO on 2019
# Not sampled: GORONTALO on 2016
# Not sampled: GORONTALO on 2014
# Not sampled: GORONTALO on 2013
# Not sampled: GORONTALO on 2011
# Not sampled: SULAWESI BARAT on 2022
# Not sampled: SULAWESI BARAT on 2020
# Not sampled: SULAWESI BARAT on 2018
# Not sampled: SULAWESI BARAT on 2017
# Not sampled: SULAWESI BARAT on 2015
# Not sampled: SULAWESI BARAT on 2014
# Not sampled: SULAWESI BARAT on 2013
# Not sampled: SULAWESI BARAT on 2012
# Not sampled: MALUKU on Provinsi
# Not sampled: MALUKU on 2022
# Not sampled: MALUKU on 2020
# Not sampled: MALUKU on 2017
# Not sampled: MALUKU on 2016
# Not sampled: MALUKU on 2015
# Not sampled: MALUKU on 2013
# Not sampled: MALUKU UTARA on Provinsi
# Not sampled: MALUKU UTARA on 2022
# Not sampled: MALUKU UTARA on 2018
# Not sampled: MALUKU UTARA on 2017
# Not sampled: MALUKU UTARA on 2016
# Not sampled: MALUKU UTARA on 2014
# Not sampled: MALUKU UTARA on 2012
# Not sampled: MALUKU UTARA on 2010
# Not sampled: PAPUA BARAT on 2022
# Not sampled: PAPUA BARAT on 2021
# Not sampled: PAPUA BARAT on 2016
# Not sampled: PAPUA BARAT on 2015
# Not sampled: PAPUA BARAT on 2013
# Not sampled: PAPUA BARAT on 2012
# Not sampled: PAPUA BARAT on 2010
# Not sampled: PAPUA on 2022
# Not sampled: PAPUA on 2020
# Not sampled: PAPUA on 2018
# Not sampled: PAPUA on 2017
# Not sampled: PAPUA on 2016
# Not sampled: PAPUA on 2015
# Not sampled: PAPUA on 2014
# Not sampled: PAPUA on 2011
# Not sampled: PAPUA on 2010
# Not sampled: INDONESIA on 2021
# Not sampled: INDONESIA on 2020
# Not sampled: INDONESIA on 2019
# Not sampled: INDONESIA on 2018
# Not sampled: INDONESIA on 2017
# Not sampled: INDONESIA on 2016
# Not sampled: INDONESIA on 2015
# Not sampled: INDONESIA on 2013
# Total question-answer: 457

# %% [markdown]
# ### check for dupes

# %%
ds = pd.read_csv('table_csv/angka_harapan_hidup_provinsi_indonesia.csv', sep = ';')
ds = ds.astype('str')

# %%
for id in ds.index:
    lis = []
    for col in ds.columns:
        if col == "Provinsi" or col =='Jenis Kelamin':
            continue
        
        
        lis.append(ds.loc[id,col])
    if len(set(lis)) < 13:
        print(ds.loc[id,'Provinsi'])
